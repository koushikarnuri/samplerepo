# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
Exp=[1,2,4,5,6]
Salary=[1000,2000,4000,5000,10000]

# %%
## Line chart
plt.plot(Exp,Salary,color='red',marker='*',markerfacecolor='blue',markersize=10)
